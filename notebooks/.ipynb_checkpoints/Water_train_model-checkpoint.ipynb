# %%
# ============================================================================
# IMPORTS
# ============================================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import joblib
import os
from datetime import datetime

# Configuration
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✅ Imports OK")
print(f"TensorFlow version: {tf.__version__}")
print(f"Numpy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# ✅ Imports OK
# TensorFlow version: 2.16.1
# Numpy version: 1.26.4
# Pandas version: 2.3.3

# %%
# ============================================================================
# 1. CHARGEMENT DES DONNÉES
# ============================================================================

print("\n" + "="*60)
print("📂 CHARGEMENT DES DONNÉES")
print("="*60)

# Chemins
DATA_DIR = "../data/water_training_split"
MODEL_DIR = "api/ml"

# Créer le dossier de sortie si besoin
os.makedirs(MODEL_DIR, exist_ok=True)

# Chargement
train_df = pd.read_csv(f"{DATA_DIR}/train.csv")
val_df = pd.read_csv(f"{DATA_DIR}/val.csv")
test_df = pd.read_csv(f"{DATA_DIR}/test.csv")

print(f"✓ Train: {train_df.shape[0]} échantillons")
print(f"✓ Val:   {val_df.shape[0]} échantillons")
print(f"✓ Test:  {test_df.shape[0]} échantillons")

# Affichage des premières lignes
print("\n📊 Aperçu des données (train):")
print(train_df.head())
# Out:
# ============================================================
# 📂 CHARGEMENT DES DONNÉES
# ============================================================
# ✓ Train: 700 échantillons
# ✓ Val:   150 échantillons
# ✓ Test:  150 échantillons
#
# 📊 Aperçu des données (train):
#    temperature_celsius  humidity_percent  rainfall_mm  evapotranspiration_mm  \
# 0                 25.1              78.1         38.1                    3.9
# 1                 27.7              84.6          7.5                    4.4
# 2                 29.0              84.1          8.5                    4.2
# 3                 20.4              80.4         12.5                    4.2
# 4                 29.2              92.2          4.5                    5.0
#
#    wind_speed_kmh  soil_moisture_percent soil_type growth_stage  \
# 0             6.7                   82.7      peat  germination
# 1            23.0                   88.3      clay   vegetative
# 2            15.0                   68.2      peat  germination
# 3            18.9                   40.4      peat   maturation
# 4            22.8                   70.3     loamy   maturation
#
#   irrigation_method  soil_type_encoded  growth_stage_encoded  \
# 0               awd                  3                     0
# 1           flooded                  0                     1
# 2               sri                  3                     0
# 3               sri                  3                     3
# 4               awd                  1                     3
#
#    irrigation_method_encoded  water_need_mm_per_day season    sample_id
# 0                          2                   6.93  rainy  sample_0521
# 1                          0                  90.39  rainy  sample_0737
# 2                          1                  26.47  rainy  sample_0740
# 3                          1                  37.24  rainy  sample_0660
# 4                          2                  52.08  rainy  sample_0411

# %%
# ============================================================================
# 2. ANALYSE EXPLORATOIRE (EDA)
# ============================================================================

print("\n" + "="*60)
print("📊 ANALYSE EXPLORATOIRE")
print("="*60)

# Statistiques descriptives
print("\n📈 Statistiques de la variable cible (water_need_mm_per_day):")
print(train_df['water_need_mm_per_day'].describe())

# Distribution de la cible
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.hist(train_df['water_need_mm_per_day'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Besoins en eau (mm/jour)')
plt.ylabel('Fréquence')
plt.title('Distribution des besoins en eau')

plt.subplot(1, 3, 2)
plt.boxplot([
    train_df[train_df['growth_stage']=='germination']['water_need_mm_per_day'],
    train_df[train_df['growth_stage']=='vegetative']['water_need_mm_per_day'],
    train_df[train_df['growth_stage']=='reproductive']['water_need_mm_per_day'],
    train_df[train_df['growth_stage']=='maturation']['water_need_mm_per_day']
])
plt.xticks([1, 2, 3, 4], ['Germination', 'Végétatif', 'Reproductif', 'Maturation'], rotation=45)
plt.ylabel('Besoins en eau (mm/jour)')
plt.title('Besoins selon stade de croissance')

plt.subplot(1, 3, 3)
plt.scatter(train_df['temperature_celsius'], train_df['water_need_mm_per_day'], alpha=0.3)
plt.xlabel('Température (°C)')
plt.ylabel('Besoins en eau (mm/jour)')
plt.title('Température vs Besoins en eau')

plt.tight_layout()
plt.savefig(f'{MODEL_DIR}/eda_analysis.png', dpi=150)
print(f"✓ Graphiques sauvegardés: {MODEL_DIR}/eda_analysis.png")

# Matrice de corrélation
print("\n🔗 Corrélations avec la variable cible:")
numerical_features = ['temperature_celsius', 'humidity_percent', 'rainfall_mm', 
                      'evapotranspiration_mm', 'wind_speed_kmh', 'soil_moisture_percent']
correlations = train_df[numerical_features + ['water_need_mm_per_day']].corr()['water_need_mm_per_day'].sort_values(ascending=False)
print(correlations)
# Out:
# ============================================================
# 📊 ANALYSE EXPLORATOIRE
# ============================================================
#
# 📈 Statistiques de la variable cible (water_need_mm_per_day):
# count    700.000000
# mean      64.797486
# std       26.074515
# min        6.250000
# 25%       43.777500
# 50%       61.485000
# 75%       93.572500
# max      100.000000
# Name: water_need_mm_per_day, dtype: float64
# ✓ Graphiques sauvegardés: api/ml/eda_analysis.png
#
# 🔗 Corrélations avec la variable cible:
# water_need_mm_per_day    1.000000
# wind_speed_kmh           0.061792
# temperature_celsius     -0.000596
# evapotranspiration_mm   -0.002175
# humidity_percent        -0.029731
# rainfall_mm             -0.202689
# soil_moisture_percent   -0.239359
# Name: water_need_mm_per_day, dtype: float64

# %%
# ============================================================================
# 3. PRÉPARATION DES DONNÉES
# ============================================================================

print("\n" + "="*60)
print("🔧 PRÉPARATION DES DONNÉES")
print("="*60)

# Features à utiliser
NUMERICAL_FEATURES = [
    'temperature_celsius',
    'humidity_percent', 
    'rainfall_mm',
    'evapotranspiration_mm',
    'wind_speed_kmh',
    'soil_moisture_percent'
]

CATEGORICAL_FEATURES = [
    'soil_type_encoded',
    'growth_stage_encoded',
    'irrigation_method_encoded'
]

ALL_FEATURES = NUMERICAL_FEATURES + CATEGORICAL_FEATURES
TARGET = 'water_need_mm_per_day'

# Extraction X et y
X_train = train_df[ALL_FEATURES].values
y_train = train_df[TARGET].values

X_val = val_df[ALL_FEATURES].values
y_val = val_df[TARGET].values

X_test = test_df[ALL_FEATURES].values
y_test = test_df[TARGET].values

print(f"✓ X_train shape: {X_train.shape}")
print(f"✓ X_val shape: {X_val.shape}")
print(f"✓ X_test shape: {X_test.shape}")

# Normalisation (important pour les réseaux de neurones)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Sauvegarder le scaler
joblib.dump(scaler, f'{MODEL_DIR}/water_scaler.pkl')
print(f"✓ Scaler sauvegardé: {MODEL_DIR}/water_scaler.pkl")
# Out:
# ============================================================
# 🔧 PRÉPARATION DES DONNÉES
# ============================================================
# ✓ X_train shape: (700, 9)
# ✓ X_val shape: (150, 9)
# ✓ X_test shape: (150, 9)
# ✓ Scaler sauvegardé: api/ml/water_scaler.pkl

# %%
# ============================================================================
# 4. MODÈLE 1 : RANDOM FOREST (BASELINE)
# ============================================================================

print("\n" + "="*60)
print("🌲 ENTRAÎNEMENT RANDOM FOREST")
print("="*60)

# Entraînement
rf_model = RandomForestRegressor(
    n_estimators=100,
    max_depth=15,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

print("⏳ Entraînement en cours...")
rf_model.fit(X_train, y_train)

# Prédictions
y_train_pred_rf = rf_model.predict(X_train)
y_val_pred_rf = rf_model.predict(X_val)
y_test_pred_rf = rf_model.predict(X_test)

# Évaluation
def evaluate_model(y_true, y_pred, set_name=""):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    
    print(f"\n📊 Métriques {set_name}:")
    print(f"   MAE:  {mae:.2f} mm/jour")
    print(f"   RMSE: {rmse:.2f} mm/jour")
    print(f"   R²:   {r2:.4f}")
    
    return {'mae': mae, 'rmse': rmse, 'r2': r2}

rf_train_metrics = evaluate_model(y_train, y_train_pred_rf, "Train RF")
rf_val_metrics = evaluate_model(y_val, y_val_pred_rf, "Validation RF")
rf_test_metrics = evaluate_model(y_test, y_test_pred_rf, "Test RF")

# Importance des features
feature_importance = pd.DataFrame({
    'feature': ALL_FEATURES,
    'importance': rf_model.feature_importances_
}).sort_values('importance', ascending=False)

print("\n🔍 Importance des features (Random Forest):")
print(feature_importance)

# Sauvegarder le modèle
joblib.dump(rf_model, f'{MODEL_DIR}/water_model_rf.pkl')
print(f"✓ Modèle RF sauvegardé: {MODEL_DIR}/water_model_rf.pkl")
# Out:
# ============================================================
# 🌲 ENTRAÎNEMENT RANDOM FOREST
# ============================================================
# ⏳ Entraînement en cours...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# 📊 Métriques Train RF:
#    MAE:  1.63 mm/jour
#    RMSE: 2.83 mm/jour
#    R²:   0.9882
#
# 📊 Métriques Validation RF:
#    MAE:  2.99 mm/jour
#    RMSE: 4.44 mm/jour
#    R²:   0.9697
#
# 📊 Métriques Test RF:
#    MAE:  2.65 mm/jour
#    RMSE: 3.93 mm/jour
#    R²:   0.9771
#
# 🔍 Importance des features (Random Forest):
#                      feature  importance
# 8  irrigation_method_encoded    0.627588
# 7       growth_stage_encoded    0.187108
# 5      soil_moisture_percent    0.096692
# 2                rainfall_mm    0.067376
# 0        temperature_celsius    0.010408
# 3      evapotranspiration_mm    0.003704
# 4             wind_speed_kmh    0.002839
# 1           humidity_percent    0.002752
# 6          soil_type_encoded    0.001533
# ✓ Modèle RF sauvegardé: api/ml/water_model_rf.pkl

# %%
# ============================================================================
# 5. MODÈLE 2 : LSTM (DEEP LEARNING)
# ============================================================================

print("\n" + "="*60)
print("🧠 ENTRAÎNEMENT LSTM")
print("="*60)

# Pour LSTM, on doit reshaper les données (samples, timesteps, features)
# Ici on utilise timesteps=1 car chaque prédiction est indépendante
X_train_lstm = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_val_lstm = X_val_scaled.reshape((X_val_scaled.shape[0], 1, X_val_scaled.shape[1]))
X_test_lstm = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

print(f"✓ X_train_lstm shape: {X_train_lstm.shape}")

# Architecture du modèle
def create_lstm_model(input_shape):
    model = keras.Sequential([
        # Couche LSTM
        layers.LSTM(64, activation='relu', return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        
        layers.LSTM(32, activation='relu'),
        layers.Dropout(0.2),
        
        # Couches denses
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.1),
        
        layers.Dense(16, activation='relu'),
        
        # Sortie
        layers.Dense(1)
    ])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )
    
    return model

# Créer le modèle
lstm_model = create_lstm_model((X_train_lstm.shape[1], X_train_lstm.shape[2]))

print("\n📐 Architecture du modèle:")
lstm_model.summary()

# Callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=f'{MODEL_DIR}/water_model_lstm_best.h5',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-6,
        verbose=1
    )
]

# Entraînement
print("\n⏳ Entraînement en cours...")
history = lstm_model.fit(
    X_train_lstm, y_train,
    validation_data=(X_val_lstm, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# Sauvegarder le modèle final
lstm_model.save(f'{MODEL_DIR}/water_model.h5')
print(f"✓ Modèle LSTM sauvegardé: {MODEL_DIR}/water_model.h5")

# Prédictions
y_train_pred_lstm = lstm_model.predict(X_train_lstm).flatten()
y_val_pred_lstm = lstm_model.predict(X_val_lstm).flatten()
y_test_pred_lstm = lstm_model.predict(X_test_lstm).flatten()

# Évaluation
lstm_train_metrics = evaluate_model(y_train, y_train_pred_lstm, "Train LSTM")
lstm_val_metrics = evaluate_model(y_val, y_val_pred_lstm, "Validation LSTM")
lstm_test_metrics = evaluate_model(y_test, y_test_pred_lstm, "Test LSTM")
# Out:
# ============================================================
# 🧠 ENTRAÎNEMENT LSTM
# ============================================================
# ✓ X_train_lstm shape: (700, 1, 9)
# C:\Users\PC\anaconda3\envs\tf310\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 📐 Architecture du modèle:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 64)               │          18,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,961 (128.75 KB)
#  Trainable params: 32,961 (128.75 KB)
#  Non-trainable params: 0 (0.00 B)
# ⏳ Entraînement en cours...
# Epoch 1/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4910.7256 - mae: 64.7630
# Epoch 1: val_loss improved from None to 4663.59668, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 4863.3472 - mae: 64.6880 - val_loss: 4663.5967 - val_mae: 63.3457 - learning_rate: 0.0010
# Epoch 2/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4732.7470 - mae: 63.4940
# Epoch 2: val_loss improved from 4663.59668 to 4563.85693, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4803.0854 - mae: 64.2233 - val_loss: 4563.8569 - val_mae: 62.5653 - learning_rate: 0.0010
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4481.4226 - mae: 61.7648
# Epoch 3: val_loss improved from 4563.85693 to 4183.18359, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4603.9688 - mae: 62.6922 - val_loss: 4183.1836 - val_mae: 59.5551 - learning_rate: 0.0010
# Epoch 4/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4183.1084 - mae: 59.7684
# Epoch 4: val_loss improved from 4183.18359 to 2631.59155, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3823.0854 - mae: 56.2409 - val_loss: 2631.5916 - val_mae: 45.5553 - learning_rate: 0.0010
# Epoch 5/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2479.5558 - mae: 43.9318
# Epoch 5: val_loss improved from 2631.59155 to 788.05420, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1705.3824 - mae: 34.6147 - val_loss: 788.0542 - val_mae: 22.2609 - learning_rate: 0.0010
# Epoch 6/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 875.9027 - mae: 23.3488
# Epoch 6: val_loss improved from 788.05420 to 612.00977, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 888.6585 - mae: 23.6220 - val_loss: 612.0098 - val_mae: 20.4323 - learning_rate: 0.0010
# Epoch 7/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 856.5230 - mae: 23.5415
# Epoch 7: val_loss improved from 612.00977 to 522.18781, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 792.8330 - mae: 22.8386 - val_loss: 522.1878 - val_mae: 18.4996 - learning_rate: 0.0010
# Epoch 8/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 723.5738 - mae: 21.9080
# Epoch 8: val_loss improved from 522.18781 to 474.82214, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 698.5004 - mae: 21.2722 - val_loss: 474.8221 - val_mae: 17.6798 - learning_rate: 0.0010
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 615.5843 - mae: 19.8639
# Epoch 9: val_loss improved from 474.82214 to 429.00720, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 631.7073 - mae: 20.2709 - val_loss: 429.0072 - val_mae: 16.7373 - learning_rate: 0.0010
# Epoch 10/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 638.8649 - mae: 20.2730
# Epoch 10: val_loss improved from 429.00720 to 399.45410, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 589.6843 - mae: 19.6509 - val_loss: 399.4541 - val_mae: 16.2250 - learning_rate: 0.0010
# Epoch 11/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 560.2312 - mae: 19.5794
# Epoch 11: val_loss improved from 399.45410 to 364.08621, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 555.1831 - mae: 19.2126 - val_loss: 364.0862 - val_mae: 15.3933 - learning_rate: 0.0010
# Epoch 12/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 516.7453 - mae: 18.3327
# Epoch 12: val_loss improved from 364.08621 to 343.89215, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 511.7921 - mae: 18.1763 - val_loss: 343.8922 - val_mae: 15.1414 - learning_rate: 0.0010
# Epoch 13/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 531.7391 - mae: 18.7846
# Epoch 13: val_loss improved from 343.89215 to 315.11554, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 509.2068 - mae: 18.2257 - val_loss: 315.1155 - val_mae: 14.3323 - learning_rate: 0.0010
# Epoch 14/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 460.9158 - mae: 17.3665
# Epoch 14: val_loss improved from 315.11554 to 299.19025, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 468.6984 - mae: 17.4062 - val_loss: 299.1902 - val_mae: 13.9733 - learning_rate: 0.0010
# Epoch 15/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 408.7432 - mae: 16.3021
# Epoch 15: val_loss improved from 299.19025 to 270.09903, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 422.8456 - mae: 16.5327 - val_loss: 270.0990 - val_mae: 13.5172 - learning_rate: 0.0010
# Epoch 16/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 420.8432 - mae: 16.7619
# Epoch 16: val_loss improved from 270.09903 to 251.28961, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 402.3036 - mae: 16.2110 - val_loss: 251.2896 - val_mae: 12.9691 - learning_rate: 0.0010
# Epoch 17/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 368.4339 - mae: 15.5340
# Epoch 17: val_loss improved from 251.28961 to 238.56464, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 382.0392 - mae: 15.7857 - val_loss: 238.5646 - val_mae: 12.6536 - learning_rate: 0.0010
# Epoch 18/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 412.1961 - mae: 16.7974
# Epoch 18: val_loss improved from 238.56464 to 223.56342, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 374.8768 - mae: 15.9352 - val_loss: 223.5634 - val_mae: 12.3715 - learning_rate: 0.0010
# Epoch 19/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 348.5145 - mae: 14.8612
# Epoch 19: val_loss improved from 223.56342 to 217.81245, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 363.7150 - mae: 15.3808 - val_loss: 217.8125 - val_mae: 12.0636 - learning_rate: 0.0010
# Epoch 20/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 379.6444 - mae: 15.7282
# Epoch 20: val_loss improved from 217.81245 to 204.89067, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 344.3470 - mae: 15.0640 - val_loss: 204.8907 - val_mae: 11.8213 - learning_rate: 0.0010
# Epoch 21/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 328.2971 - mae: 14.8990
# Epoch 21: val_loss improved from 204.89067 to 196.55499, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 331.6635 - mae: 14.9577 - val_loss: 196.5550 - val_mae: 11.7798 - learning_rate: 0.0010
# Epoch 22/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 328.1985 - mae: 14.7228
# Epoch 22: val_loss did not improve from 196.55499
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 338.2589 - mae: 14.8309 - val_loss: 197.7939 - val_mae: 11.6450 - learning_rate: 0.0010
# Epoch 23/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 303.3905 - mae: 14.1035
# Epoch 23: val_loss improved from 196.55499 to 179.28206, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 306.2577 - mae: 14.0001 - val_loss: 179.2821 - val_mae: 11.1994 - learning_rate: 0.0010
# Epoch 24/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 290.8407 - mae: 13.6821
# Epoch 24: val_loss did not improve from 179.28206
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 300.7675 - mae: 14.0009 - val_loss: 179.4153 - val_mae: 11.1611 - learning_rate: 0.0010
# Epoch 25/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 305.5830 - mae: 14.0874
# Epoch 25: val_loss improved from 179.28206 to 175.10355, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 311.0875 - mae: 14.2888 - val_loss: 175.1035 - val_mae: 11.1549 - learning_rate: 0.0010
# Epoch 26/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 303.4817 - mae: 14.3040
# Epoch 26: val_loss improved from 175.10355 to 169.71294, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 309.6506 - mae: 14.2296 - val_loss: 169.7129 - val_mae: 10.9692 - learning_rate: 0.0010
# Epoch 27/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 293.2111 - mae: 14.1421
# Epoch 27: val_loss improved from 169.71294 to 165.14919, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 303.5219 - mae: 14.1942 - val_loss: 165.1492 - val_mae: 10.8352 - learning_rate: 0.0010
# Epoch 28/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 291.0307 - mae: 14.0216
# Epoch 28: val_loss did not improve from 165.14919
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 293.4143 - mae: 13.9238 - val_loss: 168.9787 - val_mae: 10.9561 - learning_rate: 0.0010
# Epoch 29/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 278.0628 - mae: 13.5780
# Epoch 29: val_loss improved from 165.14919 to 164.47575, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 294.5353 - mae: 13.9325 - val_loss: 164.4758 - val_mae: 10.8128 - learning_rate: 0.0010
# Epoch 30/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 297.5758 - mae: 14.0569
# Epoch 30: val_loss improved from 164.47575 to 161.01283, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 302.6471 - mae: 14.0985 - val_loss: 161.0128 - val_mae: 10.7144 - learning_rate: 0.0010
# Epoch 31/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 291.0540 - mae: 13.9497
# Epoch 31: val_loss did not improve from 161.01283
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 298.0425 - mae: 14.1676 - val_loss: 169.7466 - val_mae: 10.9952 - learning_rate: 0.0010
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 294.5202 - mae: 14.0946
# Epoch 32: val_loss did not improve from 161.01283
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 287.8377 - mae: 13.8379 - val_loss: 164.2659 - val_mae: 10.7779 - learning_rate: 0.0010
# Epoch 33/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 265.2533 - mae: 13.1532
# Epoch 33: val_loss did not improve from 161.01283
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 282.3895 - mae: 13.6292 - val_loss: 163.5195 - val_mae: 10.6283 - learning_rate: 0.0010
# Epoch 34/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 287.5436 - mae: 13.5658
# Epoch 34: val_loss did not improve from 161.01283
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 279.1873 - mae: 13.2636 - val_loss: 165.6702 - val_mae: 10.9003 - learning_rate: 0.0010
# Epoch 35/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 292.3358 - mae: 13.8043
# Epoch 35: val_loss improved from 161.01283 to 157.38606, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 274.0263 - mae: 13.6401 - val_loss: 157.3861 - val_mae: 10.6782 - learning_rate: 0.0010
# Epoch 36/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 267.2494 - mae: 13.2987
# Epoch 36: val_loss did not improve from 157.38606
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 278.1281 - mae: 13.4214 - val_loss: 168.2615 - val_mae: 10.7284 - learning_rate: 0.0010
# Epoch 37/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 231.0345 - mae: 12.5310
# Epoch 37: val_loss improved from 157.38606 to 152.40894, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 255.1299 - mae: 13.0660 - val_loss: 152.4089 - val_mae: 10.4624 - learning_rate: 0.0010
# Epoch 38/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 318.1687 - mae: 14.1808
# Epoch 38: val_loss did not improve from 152.40894
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 285.5432 - mae: 13.4485 - val_loss: 154.6725 - val_mae: 10.4248 - learning_rate: 0.0010
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 242.7571 - mae: 12.4335
# Epoch 39: val_loss improved from 152.40894 to 147.77188, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 262.3651 - mae: 13.1740 - val_loss: 147.7719 - val_mae: 10.3308 - learning_rate: 0.0010
# Epoch 40/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 261.1229 - mae: 13.0449
# Epoch 40: val_loss did not improve from 147.77188
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 269.0674 - mae: 13.3779 - val_loss: 150.6904 - val_mae: 10.2637 - learning_rate: 0.0010
# Epoch 41/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 258.1523 - mae: 13.0176
# Epoch 41: val_loss did not improve from 147.77188
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 252.6145 - mae: 12.6865 - val_loss: 148.6844 - val_mae: 10.1648 - learning_rate: 0.0010
# Epoch 42/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 252.7482 - mae: 12.8210
# Epoch 42: val_loss did not improve from 147.77188
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 260.3846 - mae: 13.0482 - val_loss: 151.6125 - val_mae: 10.2292 - learning_rate: 0.0010
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 261.4468 - mae: 13.0249
# Epoch 43: val_loss improved from 147.77188 to 147.28180, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 244.9552 - mae: 12.5550 - val_loss: 147.2818 - val_mae: 10.3538 - learning_rate: 0.0010
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 298.4835 - mae: 14.2377
# Epoch 44: val_loss improved from 147.28180 to 145.72261, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 275.9492 - mae: 13.5086 - val_loss: 145.7226 - val_mae: 10.1436 - learning_rate: 0.0010
# Epoch 45/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 267.1025 - mae: 13.3206
# Epoch 45: val_loss improved from 145.72261 to 143.88643, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 257.7036 - mae: 12.8889 - val_loss: 143.8864 - val_mae: 10.1148 - learning_rate: 0.0010
# Epoch 46/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 253.6332 - mae: 12.9080
# Epoch 46: val_loss did not improve from 143.88643
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 250.1644 - mae: 12.8302 - val_loss: 147.1772 - val_mae: 10.2317 - learning_rate: 0.0010
# Epoch 47/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 236.3876 - mae: 12.4461
# Epoch 47: val_loss improved from 143.88643 to 142.34682, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 248.7257 - mae: 12.7550 - val_loss: 142.3468 - val_mae: 10.0830 - learning_rate: 0.0010
# Epoch 48/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 252.1127 - mae: 12.9107
# Epoch 48: val_loss did not improve from 142.34682
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 241.4256 - mae: 12.6760 - val_loss: 143.3701 - val_mae: 10.0618 - learning_rate: 0.0010
# Epoch 49/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 278.2377 - mae: 13.4538
# Epoch 49: val_loss improved from 142.34682 to 140.93765, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 260.6128 - mae: 13.0876 - val_loss: 140.9377 - val_mae: 10.0566 - learning_rate: 0.0010
# Epoch 50/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 219.4545 - mae: 12.2118
# Epoch 50: val_loss did not improve from 140.93765
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 240.1992 - mae: 12.5766 - val_loss: 144.2073 - val_mae: 9.9633 - learning_rate: 0.0010
# Epoch 51/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 232.8205 - mae: 12.2480
# Epoch 51: val_loss improved from 140.93765 to 138.14017, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 228.8718 - mae: 12.2081 - val_loss: 138.1402 - val_mae: 9.9044 - learning_rate: 0.0010
# Epoch 52/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 234.4574 - mae: 12.4287
# Epoch 52: val_loss improved from 138.14017 to 134.79411, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 230.1493 - mae: 12.2451 - val_loss: 134.7941 - val_mae: 9.7557 - learning_rate: 0.0010
# Epoch 53/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 232.1746 - mae: 12.4231
# Epoch 53: val_loss improved from 134.79411 to 133.90685, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 242.8491 - mae: 12.7068 - val_loss: 133.9068 - val_mae: 9.7136 - learning_rate: 0.0010
# Epoch 54/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 213.2444 - mae: 11.6975
# Epoch 54: val_loss improved from 133.90685 to 131.84380, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 228.5341 - mae: 12.3546 - val_loss: 131.8438 - val_mae: 9.6289 - learning_rate: 0.0010
# Epoch 55/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 234.5904 - mae: 12.5050
# Epoch 55: val_loss improved from 131.84380 to 129.99722, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 231.2004 - mae: 12.2896 - val_loss: 129.9972 - val_mae: 9.6083 - learning_rate: 0.0010
# Epoch 56/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 223.3392 - mae: 11.7697
# Epoch 56: val_loss improved from 129.99722 to 127.20830, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 229.5725 - mae: 12.1188 - val_loss: 127.2083 - val_mae: 9.4511 - learning_rate: 0.0010
# Epoch 57/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 231.2707 - mae: 12.4442
# Epoch 57: val_loss did not improve from 127.20830
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 244.1102 - mae: 12.7677 - val_loss: 134.0687 - val_mae: 9.6227 - learning_rate: 0.0010
# Epoch 58/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 241.2788 - mae: 12.6857
# Epoch 58: val_loss improved from 127.20830 to 124.89414, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 234.3100 - mae: 12.5840 - val_loss: 124.8941 - val_mae: 9.3188 - learning_rate: 0.0010
# Epoch 59/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 236.2607 - mae: 12.3430
# Epoch 59: val_loss improved from 124.89414 to 124.83378, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 234.2061 - mae: 12.4312 - val_loss: 124.8338 - val_mae: 9.3494 - learning_rate: 0.0010
# Epoch 60/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 218.2486 - mae: 11.8324
# Epoch 60: val_loss improved from 124.83378 to 119.94841, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 218.3096 - mae: 11.9728 - val_loss: 119.9484 - val_mae: 9.1677 - learning_rate: 0.0010
# Epoch 61/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 221.4175 - mae: 12.1125
# Epoch 61: val_loss improved from 119.94841 to 115.82580, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 221.2054 - mae: 12.0654 - val_loss: 115.8258 - val_mae: 8.9431 - learning_rate: 0.0010
# Epoch 62/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 222.1186 - mae: 12.0942
# Epoch 62: val_loss did not improve from 115.82580
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 212.5542 - mae: 11.8168 - val_loss: 118.3968 - val_mae: 9.1132 - learning_rate: 0.0010
# Epoch 63/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 210.8809 - mae: 11.5038
# Epoch 63: val_loss improved from 115.82580 to 111.19508, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 215.9215 - mae: 11.5312 - val_loss: 111.1951 - val_mae: 8.8569 - learning_rate: 0.0010
# Epoch 64/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 210.0152 - mae: 12.0042
# Epoch 64: val_loss improved from 111.19508 to 110.03612, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 193.6256 - mae: 11.2470 - val_loss: 110.0361 - val_mae: 8.6380 - learning_rate: 0.0010
# Epoch 65/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 203.1526 - mae: 11.4361
# Epoch 65: val_loss improved from 110.03612 to 108.27616, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 203.9368 - mae: 11.5431 - val_loss: 108.2762 - val_mae: 8.5249 - learning_rate: 0.0010
# Epoch 66/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 205.9583 - mae: 11.6467
# Epoch 66: val_loss improved from 108.27616 to 104.73981, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 208.8582 - mae: 11.6175 - val_loss: 104.7398 - val_mae: 8.4702 - learning_rate: 0.0010
# Epoch 67/100
# 12/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 199.8780 - mae: 11.2941
# Epoch 67: val_loss improved from 104.73981 to 103.71039, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 195.7632 - mae: 11.2940 - val_loss: 103.7104 - val_mae: 8.5503 - learning_rate: 0.0010
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 190.8613 - mae: 10.9412
# Epoch 68: val_loss improved from 103.71039 to 95.65297, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 181.3252 - mae: 10.8557 - val_loss: 95.6530 - val_mae: 8.0186 - learning_rate: 0.0010
# Epoch 69/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 184.8425 - mae: 10.9583
# Epoch 69: val_loss improved from 95.65297 to 94.81178, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 178.6807 - mae: 10.8139 - val_loss: 94.8118 - val_mae: 7.9251 - learning_rate: 0.0010
# Epoch 70/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190.3897 - mae: 11.2000
# Epoch 70: val_loss did not improve from 94.81178
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 186.3464 - mae: 10.9061 - val_loss: 95.7780 - val_mae: 7.9624 - learning_rate: 0.0010
# Epoch 71/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 182.9344 - mae: 10.6801
# Epoch 71: val_loss improved from 94.81178 to 90.14805, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 181.7102 - mae: 10.7541 - val_loss: 90.1480 - val_mae: 7.6454 - learning_rate: 0.0010
# Epoch 72/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 190.1150 - mae: 10.7410
# Epoch 72: val_loss did not improve from 90.14805
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 189.6430 - mae: 10.7778 - val_loss: 104.0173 - val_mae: 8.4788 - learning_rate: 0.0010
# Epoch 73/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 198.2852 - mae: 11.3841
# Epoch 73: val_loss improved from 90.14805 to 87.84901, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 186.9427 - mae: 10.9290 - val_loss: 87.8490 - val_mae: 7.6524 - learning_rate: 0.0010
# Epoch 74/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 176.5015 - mae: 10.4453
# Epoch 74: val_loss improved from 87.84901 to 85.05250, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 183.3014 - mae: 10.7300 - val_loss: 85.0525 - val_mae: 7.3300 - learning_rate: 0.0010
# Epoch 75/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183.6804 - mae: 10.7937
# Epoch 75: val_loss improved from 85.05250 to 82.54499, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 171.4060 - mae: 10.4293 - val_loss: 82.5450 - val_mae: 7.4253 - learning_rate: 0.0010
# Epoch 76/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 161.4743 - mae: 10.2802
# Epoch 76: val_loss improved from 82.54499 to 79.18246, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 164.3597 - mae: 10.2702 - val_loss: 79.1825 - val_mae: 7.1776 - learning_rate: 0.0010
# Epoch 77/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 169.4247 - mae: 10.2314
# Epoch 77: val_loss improved from 79.18246 to 76.58736, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 178.7934 - mae: 10.5378 - val_loss: 76.5874 - val_mae: 7.0192 - learning_rate: 0.0010
# Epoch 78/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 155.0689 - mae: 10.0457
# Epoch 78: val_loss improved from 76.58736 to 75.92221, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 150.4187 - mae: 9.7749 - val_loss: 75.9222 - val_mae: 7.0300 - learning_rate: 0.0010
# Epoch 79/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 161.2750 - mae: 9.9404
# Epoch 79: val_loss improved from 75.92221 to 73.68073, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 165.4871 - mae: 10.0179 - val_loss: 73.6807 - val_mae: 6.9178 - learning_rate: 0.0010
# Epoch 80/100
# 16/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 172.8674 - mae: 10.2639
# Epoch 80: val_loss improved from 73.68073 to 71.48688, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 154.0379 - mae: 9.7325 - val_loss: 71.4869 - val_mae: 6.9030 - learning_rate: 0.0010
# Epoch 81/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 168.8616 - mae: 10.2645
# Epoch 81: val_loss did not improve from 71.48688
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 168.5893 - mae: 10.3733 - val_loss: 74.0982 - val_mae: 6.8135 - learning_rate: 0.0010
# Epoch 82/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 164.5135 - mae: 10.2241
# Epoch 82: val_loss improved from 71.48688 to 69.60101, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 154.7589 - mae: 9.7682 - val_loss: 69.6010 - val_mae: 6.6308 - learning_rate: 0.0010
# Epoch 83/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 159.0958 - mae: 9.7972
# Epoch 83: val_loss improved from 69.60101 to 68.86822, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 152.6507 - mae: 9.7642 - val_loss: 68.8682 - val_mae: 6.7432 - learning_rate: 0.0010
# Epoch 84/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 143.5403 - mae: 9.5246
# Epoch 84: val_loss improved from 68.86822 to 65.08296, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 146.5073 - mae: 9.5268 - val_loss: 65.0830 - val_mae: 6.4095 - learning_rate: 0.0010
# Epoch 85/100
# 14/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 131.2845 - mae: 9.1498
# Epoch 85: val_loss improved from 65.08296 to 64.19291, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 154.7440 - mae: 9.9014 - val_loss: 64.1929 - val_mae: 6.3010 - learning_rate: 0.0010
# Epoch 86/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 157.1875 - mae: 10.1362
# Epoch 86: val_loss improved from 64.19291 to 63.63337, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 149.2710 - mae: 9.6377 - val_loss: 63.6334 - val_mae: 6.3301 - learning_rate: 0.0010
# Epoch 87/100
# 15/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 159.3713 - mae: 9.7263
# Epoch 87: val_loss did not improve from 63.63337
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 170.7271 - mae: 10.2086 - val_loss: 64.0381 - val_mae: 6.4356 - learning_rate: 0.0010
# Epoch 88/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 154.5343 - mae: 9.8274
# Epoch 88: val_loss did not improve from 63.63337
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 163.6788 - mae: 10.1038 - val_loss: 66.7842 - val_mae: 6.6042 - learning_rate: 0.0010
# Epoch 89/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 137.4705 - mae: 9.3522
# Epoch 89: val_loss did not improve from 63.63337
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 152.9067 - mae: 9.9132 - val_loss: 65.5425 - val_mae: 6.5314 - learning_rate: 0.0010
# Epoch 90/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 129.0956 - mae: 9.0591
# Epoch 90: val_loss did not improve from 63.63337
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 142.4208 - mae: 9.2985 - val_loss: 64.2206 - val_mae: 6.3647 - learning_rate: 0.0010
# Epoch 91/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 138.6117 - mae: 9.3816
# Epoch 91: val_loss did not improve from 63.63337
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 140.8779 - mae: 9.2945 - val_loss: 63.8045 - val_mae: 6.3338 - learning_rate: 0.0010
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 143.9951 - mae: 9.3020
# Epoch 92: val_loss improved from 63.63337 to 63.25296, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 153.4464 - mae: 9.7576 - val_loss: 63.2530 - val_mae: 6.2739 - learning_rate: 0.0010
# Epoch 93/100
# 20/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 152.4165 - mae: 9.6899
# Epoch 93: val_loss did not improve from 63.25296
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 150.8389 - mae: 9.6019 - val_loss: 63.5825 - val_mae: 6.4263 - learning_rate: 0.0010
# Epoch 94/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 153.9192 - mae: 9.6271
# Epoch 94: val_loss improved from 63.25296 to 61.26104, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 155.4442 - mae: 9.6814 - val_loss: 61.2610 - val_mae: 6.3364 - learning_rate: 0.0010
# Epoch 95/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 142.9601 - mae: 9.4344
# Epoch 95: val_loss did not improve from 61.26104
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 151.9710 - mae: 9.7501 - val_loss: 61.6747 - val_mae: 6.3333 - learning_rate: 0.0010
# Epoch 96/100
# 18/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 159.9013 - mae: 9.9363
# Epoch 96: val_loss did not improve from 61.26104
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 159.6080 - mae: 10.0038 - val_loss: 65.6299 - val_mae: 6.5969 - learning_rate: 0.0010
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 147.6691 - mae: 9.4711
# Epoch 97: val_loss improved from 61.26104 to 60.18207, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 150.5880 - mae: 9.5449 - val_loss: 60.1821 - val_mae: 6.1786 - learning_rate: 0.0010
# Epoch 98/100
# 17/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 163.3628 - mae: 10.1410
# Epoch 98: val_loss did not improve from 60.18207
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 150.5273 - mae: 9.6099 - val_loss: 64.1670 - val_mae: 6.4064 - learning_rate: 0.0010
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 135.9983 - mae: 8.9658
# Epoch 99: val_loss improved from 60.18207 to 55.13664, saving model to api/ml/water_model_lstm_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 142.9690 - mae: 9.1948 - val_loss: 55.1366 - val_mae: 5.9350 - learning_rate: 0.0010
# Epoch 100/100
# 19/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 168.3199 - mae: 10.0550
# Epoch 100: val_loss did not improve from 55.13664
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 140.8312 - mae: 9.1967 - val_loss: 59.1456 - val_mae: 6.0197 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 99.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Modèle LSTM sauvegardé: api/ml/water_model.h5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# 📊 Métriques Train LSTM:
#    MAE:  5.92 mm/jour
#    RMSE: 7.37 mm/jour
#    R²:   0.9200
#
# 📊 Métriques Validation LSTM:
#    MAE:  5.93 mm/jour
#    RMSE: 7.43 mm/jour
#    R²:   0.9153
#
# 📊 Métriques Test LSTM:
#    MAE:  6.08 mm/jour
#    RMSE: 7.84 mm/jour
#    R²:   0.9087

# %%
# ============================================================================
# 6. COMPARAISON DES MODÈLES
# ============================================================================

print("\n" + "="*60)
print("📊 COMPARAISON DES MODÈLES")
print("="*60)

comparison = pd.DataFrame({
    'Modèle': ['Random Forest', 'LSTM'],
    'MAE Test': [rf_test_metrics['mae'], lstm_test_metrics['mae']],
    'RMSE Test': [rf_test_metrics['rmse'], lstm_test_metrics['rmse']],
    'R² Test': [rf_test_metrics['r2'], lstm_test_metrics['r2']]
})

print(comparison.to_string(index=False))

# Visualisation de la courbe d'apprentissage LSTM
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Courbe d\'apprentissage - Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE (mm/jour)')
plt.title('Courbe d\'apprentissage - MAE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig(f'{MODEL_DIR}/training_curves.png', dpi=150)
print(f"✓ Courbes sauvegardées: {MODEL_DIR}/training_curves.png")

# Prédictions vs Réalité
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_test_pred_rf, alpha=0.5, s=10)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Valeurs réelles (mm/jour)')
plt.ylabel('Prédictions RF (mm/jour)')
plt.title(f'Random Forest - Test Set (R²={rf_test_metrics["r2"]:.3f})')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred_lstm, alpha=0.5, s=10)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Valeurs réelles (mm/jour)')
plt.ylabel('Prédictions LSTM (mm/jour)')
plt.title(f'LSTM - Test Set (R²={lstm_test_metrics["r2"]:.3f})')
plt.grid(True)

plt.tight_layout()
plt.savefig(f'{MODEL_DIR}/predictions_comparison.png', dpi=150)
print(f"✓ Comparaison sauvegardée: {MODEL_DIR}/predictions_comparison.png")
# Out:
# ============================================================
# 📊 COMPARAISON DES MODÈLES
# ============================================================
#        Modèle  MAE Test  RMSE Test  R² Test
# Random Forest  2.645876   3.927856 0.977103
#          LSTM  6.077762   7.842246 0.908725
# ✓ Courbes sauvegardées: api/ml/training_curves.png
# ✓ Comparaison sauvegardée: api/ml/predictions_comparison.png

# %%
# ============================================================================
# 7. TEST RAPIDE DU MODÈLE
# ============================================================================

print("\n" + "="*60)
print("🧪 TEST RAPIDE DU MODÈLE")
print("="*60)

# Charger le modèle sauvegardé
loaded_model = keras.models.load_model(f'{MODEL_DIR}/water_model.h5')
loaded_scaler = joblib.load(f'{MODEL_DIR}/water_scaler.pkl')

# Exemple de prédiction
sample = {
    'temperature_celsius': 28.5,
    'humidity_percent': 75.0,
    'rainfall_mm': 5.0,
    'evapotranspiration_mm': 4.5,
    'wind_speed_kmh': 12.0,
    'soil_moisture_percent': 65.0,
    'soil_type_encoded': 0,  # clay
    'growth_stage_encoded': 1,  # vegetative
    'irrigation_method_encoded': 1  # sri
}

sample_array = np.array([[sample[f] for f in ALL_FEATURES]])
sample_scaled = loaded_scaler.transform(sample_array)
sample_lstm = sample_scaled.reshape((1, 1, sample_scaled.shape[1]))

prediction = loaded_model.predict(sample_lstm)[0][0]

print(f"\n📊 Exemple de prédiction:")
print(f"   Température: {sample['temperature_celsius']}°C")
print(f"   Humidité: {sample['humidity_percent']}%")
print(f"   Pluie: {sample['rainfall_mm']} mm")
print(f"   → Besoin en eau prédit: {prediction:.2f} mm/jour")
# Out:
# ============================================================
# 🧪 TEST RAPIDE DU MODÈLE
# ============================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       7 print("="*60)
#       9 # Charger le modèle sauvegardé
# ---> 10 loaded_model = keras.models.load_model(f'{MODEL_DIR}/water_model.h5')
#      11 loaded_scaler = joblib.load(f'{MODEL_DIR}/water_scaler.pkl')
#      13 # Exemple de prédiction
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:159, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     155 training_config = json_utils.decode(training_config)
#     157 # Compile model.
#     158 model.compile(
# --> 159     **saving_utils.compile_args_from_training_config(
#     160         training_config, custom_objects
#     161     )
#     162 )
#     163 saving_utils.try_build_compiled_arguments(model)
#     165 # Set optimizer weights.
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\legacy\saving\saving_utils.py:143, in compile_args_from_training_config(training_config, custom_objects)
#     141 loss_config = training_config.get("loss", None)
#     142 if loss_config is not None:
# --> 143     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     144     # Ensure backwards compatibility for losses in legacy H5 files
#     145     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\legacy\saving\saving_utils.py:202, in _deserialize_nested_config(deserialize_fn, config)
#     200     return None
#     201 if _is_single_object(config):
# --> 202     return deserialize_fn(config)
#     203 elif isinstance(config, dict):
#     204     return {
#     205         k: _deserialize_nested_config(deserialize_fn, v)
#     206         for k, v in config.items()
#     207     }
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\losses\__init__.py:155, in deserialize(name, custom_objects)
#     142 @keras_export("keras.losses.deserialize")
#     143 def deserialize(name, custom_objects=None):
#     144     """Deserializes a serialized loss class/function instance.
#     145
#     146     Args:
#    (...)
#     153         A Keras `Loss` instance or a loss function.
#     154     """
# --> 155     return serialization_lib.deserialize_keras_object(
#     156         name,
#     157         module_objects=ALL_OBJECTS_DICT,
#     158         custom_objects=custom_objects,
#     159     )
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\saving\serialization_lib.py:590, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     588             return config
#     589         if isinstance(module_objects[config], types.FunctionType):
# --> 590             return deserialize_keras_object(
#     591                 serialize_with_public_fn(
#     592                     module_objects[config], config, fn_module_name
#     593                 ),
#     594                 custom_objects=custom_objects,
#     595             )
#     596         return deserialize_keras_object(
#     597             serialize_with_public_class(
#     598                 module_objects[config], inner_config=inner_config
#     599             ),
#     600             custom_objects=custom_objects,
#     601         )
#     603 if isinstance(config, PLAIN_TYPES):
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\saving\serialization_lib.py:693, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     691 if class_name == "function":
#     692     fn_name = inner_config
# --> 693     return _retrieve_class_or_fn(
#     694         fn_name,
#     695         registered_name,
#     696         module,
#     697         obj_type="function",
#     698         full_config=config,
#     699         custom_objects=custom_objects,
#     700     )
#     702 # Below, handling of all classes.
#     703 # First, is it a shared object?
#     704 if "shared_object_id" in config:
#
# File ~\anaconda3\envs\tf310\lib\site-packages\keras\src\saving\serialization_lib.py:823, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     821         return obj
#     822     else:
# --> 823         raise ValueError(
#     824             f"Could not deserialize '{module}.{name}' because "
#     825             "it is not a KerasSaveable subclass"
#     826         )
#     827 except ModuleNotFoundError:
#     828     raise TypeError(
#     829         f"Could not deserialize {obj_type} '{name}' because "
#     830         f"its parent module {module} cannot be imported. "
#     831         f"Full object config: {full_config}"
#     832     )
#
# ValueError: Could not deserialize 'keras.metrics.mse' because it is not a KerasSaveable subclass
